# %%
import torch
from db_helper_functions import get_stock_news_from_db
import numpy as np
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
)

# %%
df = get_stock_news_from_db("AAPL")
df = df[~df.article.isnull()]
t_df = df.iloc[:100]
t_df
# Out:
#       id ticker                                              title  \
# 0   4235   AAPL  Microsoft, Alphabet, Meta, Apple, And Amazon L...
# 1   4376   AAPL  Benzinga Before The Bell: More Amazon Workers ...
# 2      3   AAPL  Market Rebounds On Trade Optimism, Tech Bounce...
# 3      4   AAPL  American Shippers And Carriers React To Signs ...
# 4      5   AAPL  TD Ameritrade IMX Continued Its Dip In Decembe...
# ..   ...    ...                                                ...
# 95   133   AAPL  Mid-Afternoon Market Update: Nu Skin Enterpris...
# 96   135   AAPL                   60 Biggest Movers From Yesterday
# 97   137   AAPL  After Sliding On Powell's Words, Stocks Look F...
# 98   139   AAPL  Learn About The Everything Store To The Everyt...
# 99   142   AAPL  Tariff-Related Losses Put Pressure On Multinat...
#
#                                                   url  \
# 0   https://www.benzinga.com/news/earnings/22/07/2...
# 1   https://www.benzinga.com/news/22/08/28532545/b...
# 2              https://www.benzinga.com/node/12934767
# 3              https://www.benzinga.com/node/12938837
# 4              https://www.benzinga.com/node/12953011
# ..                                                ...
# 95             https://www.benzinga.com/node/13643990
# 96             https://www.benzinga.com/node/13649199
# 97             https://www.benzinga.com/node/13652243
# 98             https://www.benzinga.com/node/13656252
# 99             https://www.benzinga.com/node/13688513
#
#                                               article        date
# 0   (Monday Market Open) Investors appear optimist...  2022-07-25
# 1   CNBCBlackRock To Pledge A$1B In Australian Bat...  2022-08-17
# 2   A stronger-than-expected government report on ...  2019-01-04
# 3   The first week of 2019 saw three of America's ...  2019-01-07
# 4   Declining for the third month in a row, TD Ame...  2019-01-08
# ..                                                ...         ...
# 95  Toward the end of trading Wednesday, the Dow t...  2019-05-01
# 96  Loading...Loading...Gainers\nARCA biopharma, I...  2019-05-02
# 97  The Fed threw one right down the middle late W...  2019-05-02
# 98   In 2013, when Brad Stone set out to write abo...  2019-05-02
# 99  When tariff fears flare, most other market new...  2019-05-07
#
# [100 rows x 6 columns]

# %%
finbert_tokenizer = AutoTokenizer.from_pretrained("yiyanghkust/finbert-tone")

# %%
finbert_model = AutoModelForSequenceClassification.from_pretrained(
    "yiyanghkust/finbert-tone", num_labels=3
)

# %%
start_pos = 512
end_pos = 512 * 2
raw_list_data_for_finbert = [x[start_pos:end_pos] for x in t_df.article]

# %%
finbert_mat = finbert_tokenizer(
    raw_list_data_for_finbert, padding=True, return_tensors="pt"
)

# %%
outputs = finbert_model(**finbert_mat)
outputs
# Out:
# SequenceClassifierOutput(loss=None, logits=tensor([[ 0.1706, -4.9509,  8.1077],
#         [ 0.2905,  0.0974, -2.5024],
#         [-5.9380, 10.0288, -5.7915],
#         [-3.8902, -3.4970, 11.6473],
#         [-2.8115, -3.2362,  7.6035],
#         [-1.5745,  3.4449, -5.8679],
#         [-2.8695,  1.9628, -0.7169],
#         [ 4.5318, -5.4036, -1.0344],
#         [-1.2309, -4.2488,  7.3972],
#         [-5.1422, -0.7307,  9.0710],
#         [-2.7236, -3.3387,  8.9899],
#         [ 0.1838, -3.9976,  5.5663],
#         [ 2.6510, -4.4525, -1.3548],
#         [-4.6551, -2.3832, 10.8676],
#         [-7.0718, 12.0662, -6.6328],
#         [-6.0417,  8.7086, -5.7935],
#         [-1.7315, -0.2952,  3.0724],
#         [-1.9062,  3.0620, -3.3200],
#         [-3.0855, -2.0258,  8.2393],
#         [ 1.9825, -6.2243,  5.8268],
#         [ 7.8742, -6.3236, -5.7039],
#         [-1.1159, -2.4342,  6.5349],
#         [-3.4164, -3.5709, 10.9312],
#         [ 5.5781, -3.6536, -5.0314],
#         [ 1.5906, -2.7136,  0.4595],
#         [-4.2627, -0.0983,  4.3618],
#         [-3.6491, -4.5422, 12.1492],
#         [ 0.7588, -4.1183,  5.1930],
#         [-6.8525,  7.3051, -0.3933],
#         [-7.2432, 10.5394, -6.7109],
#         [ 3.2701,  0.1774, -6.5893],
#         [-7.4473, 10.7910, -5.2365],
#         [-2.9743, -4.6858,  9.6355],
#         [ 5.4242, -4.2597, -2.4673],
#         [-2.1267, -6.1445, 11.1094],
#         [ 0.2790, -2.5801,  1.1910],
#         [-1.8882,  0.6146,  0.6915],
#         [-3.8152,  0.8476,  4.1666],
#         [ 5.9867, -4.1607, -4.1625],
#         [ 1.9622, -3.1593,  1.5339],
#         [-4.5276,  7.2134, -5.9899],
#         [-1.5402,  1.1321, -0.7785],
#         [-5.3560,  3.2486,  1.8690],
#         [-7.4902, 12.0068, -6.3561],
#         [ 1.4414,  0.3092, -5.5439],
#         [-1.0732, -3.2660,  6.9497],
#         [ 6.6411, -1.8377, -6.0551],
#         [-0.6188, -1.4293,  1.6366],
#         [-4.0490, -2.3277,  9.9893],
#         [-1.2352,  5.9379, -7.4171],
#         [ 7.0333, -4.1373, -6.2803],
#         [ 6.6539, -5.4766, -3.2855],
#         [-2.1767, -3.1136,  8.4097],
#         [-5.4509,  7.8111, -4.2019],
#         [-4.5109,  3.2364,  1.6095],
#         [-5.3552,  8.6874, -4.3290],
#         [-1.1650, -2.7432,  4.3766],
#         [-2.2067,  2.0602, -0.8334],
#         [ 1.0068, -0.5683, -2.3510],
#         [-3.5783, -3.5596, 11.5264],
#         [ 0.8116, -2.6517,  1.1776],
#         [-3.9340, -2.1277, 10.0273],
#         [ 4.3880, -4.2116, -1.9235],
#         [ 6.1195, -2.0269, -7.5115],
#         [-0.8633,  0.0846, -0.1975],
#         [ 4.8063, -6.0273,  1.7156],
#         [ 0.8465, -5.3093,  6.3279],
#         [ 4.5524, -4.2417, -1.8238],
#         [-5.7368, 10.9695, -8.3440],
#         [-3.9615, -1.9514,  9.5911],
#         [-0.8193, -1.5906,  3.0532],
#         [ 1.5413, -5.0701,  3.8692],
#         [-4.4938, -2.7181, 11.6622],
#         [-4.1633,  1.8595,  2.2901],
#         [-3.8261, -2.5412,  9.1164],
#         [-6.1764,  9.4486, -6.1645],
#         [ 1.3126, -0.5087, -2.4698],
#         [-5.6250,  2.7330,  1.5844],
#         [ 0.6279,  1.6677, -5.2537],
#         [-0.9530, -2.2592,  4.6568],
#         [-1.2865, -3.5211,  6.4659],
#         [-6.4900, 11.2105, -7.0282],
#         [-4.9874,  5.8019, -3.5808],
#         [ 6.7511, -2.8585, -7.7843],
#         [-4.9010,  6.4983, -5.4723],
#         [-2.3337, -3.3103,  8.1530],
#         [ 3.3221, -6.3343,  1.4835],
#         [-1.7237, -1.7033,  4.6681],
#         [-3.8559, -1.9697,  7.9702],
#         [ 7.9195, -5.9531, -5.7682],
#         [-3.4650, -2.6852, 10.3933],
#         [-4.4863,  7.0964, -5.8880],
#         [-5.6544,  9.8472, -5.6685],
#         [-6.8849, 12.4280, -7.5620],
#         [-7.0510, 11.9508, -7.3092],
#         [-6.8642, 12.7304, -7.7609],
#         [-6.3011, 11.1948, -8.0430],
#         [ 3.7702, -5.4726,  1.0493],
#         [ 6.6797, -3.3144, -5.9906],
#         [ 0.2271, -2.5992,  3.9144]], grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
# Out:
# tensor([[3.5709e-04, 2.1309e-06, 9.9964e-01],
#         [5.3032e-01, 4.3720e-01, 3.2477e-02],
#         [1.1634e-07, 1.0000e+00, 1.3469e-07],
#         [1.7870e-07, 2.6478e-07, 1.0000e+00],
#         [2.9979e-05, 1.9606e-05, 9.9995e-01],
#         [6.5646e-03, 9.9335e-01, 8.9662e-05],
#         [7.4015e-03, 9.2889e-01, 6.3705e-02],
#         [9.9614e-01, 4.8244e-05, 3.8104e-03],
#         [1.7897e-04, 8.7516e-06, 9.9981e-01],
#         [6.7186e-07, 5.5356e-05, 9.9994e-01],
#         [8.1826e-06, 4.4232e-06, 9.9999e-01],
#         [4.5752e-03, 6.9898e-05, 9.9535e-01],
#         [9.8132e-01, 8.0691e-04, 1.7870e-02],
#         [1.8136e-07, 1.7589e-06, 1.0000e+00],
#         [4.8807e-09, 1.0000e+00, 7.5707e-09],
#         [3.9270e-07, 1.0000e+00, 5.0332e-07],
#         [7.8627e-03, 3.3062e-02, 9.5908e-01],
#         [6.8956e-03, 9.9143e-01, 1.6772e-03],
#         [1.2070e-05, 3.4825e-05, 9.9995e-01],
#         [2.0952e-02, 5.7152e-06, 9.7904e-01],
#         [1.0000e+00, 6.8233e-07, 1.2680e-06],
#         [4.7536e-04, 1.2720e-04, 9.9940e-01],
#         [5.8734e-07, 5.0327e-07, 1.0000e+00],
#         [9.9988e-01, 9.7872e-05, 2.4676e-05],
#         [7.4839e-01, 1.0112e-02, 2.4150e-01],
#         [1.7756e-04, 1.1426e-02, 9.8840e-01],
#         [1.3769e-07, 5.6367e-08, 1.0000e+00],
#         [1.1724e-02, 8.9331e-05, 9.8819e-01],
#         [7.0998e-07, 9.9955e-01, 4.5334e-04],
#         [1.8929e-08, 1.0000e+00, 3.2231e-08],
#         [9.5654e-01, 4.3408e-02, 4.9983e-05],
#         [1.2000e-08, 1.0000e+00, 1.0948e-07],
#         [3.3394e-06, 6.0307e-07, 1.0000e+00],
#         [9.9956e-01, 6.2251e-05, 3.7375e-04],
#         [1.7850e-06, 3.2118e-08, 1.0000e+00],
#         [2.8196e-01, 1.6161e-02, 7.0188e-01],
#         [3.7865e-02, 4.6256e-01, 4.9958e-01],
#         [3.2958e-04, 3.4914e-02, 9.6476e-01],
#         [9.9992e-01, 3.9174e-05, 3.9101e-05],
#         [6.0329e-01, 3.6001e-03, 3.9311e-01],
#         [7.9603e-06, 9.9999e-01, 1.8445e-06],
#         [5.6768e-02, 8.2163e-01, 1.2160e-01],
#         [1.4639e-04, 7.9881e-01, 2.0105e-01],
#         [3.4086e-09, 1.0000e+00, 1.0594e-08],
#         [7.5572e-01, 2.4358e-01, 6.9929e-04],
#         [3.2774e-04, 3.6577e-05, 9.9964e-01],
#         [9.9979e-01, 2.0779e-04, 3.0621e-06],
#         [9.1042e-02, 4.0482e-02, 8.6848e-01],
#         [8.0033e-07, 4.4750e-06, 9.9999e-01],
#         [7.6638e-04, 9.9923e-01, 1.5837e-06],
#         [9.9998e-01, 1.4082e-05, 1.6519e-06],
#         [9.9995e-01, 5.3922e-06, 4.8236e-05],
#         [2.5257e-05, 9.8970e-06, 9.9996e-01],
#         [1.7394e-06, 9.9999e-01, 6.0650e-06],
#         [3.6084e-04, 8.3544e-01, 1.6420e-01],
#         [7.9682e-07, 1.0000e+00, 2.2234e-06],
#         [3.9020e-03, 8.0515e-04, 9.9529e-01],
#         [1.3115e-02, 9.3510e-01, 5.1784e-02],
#         [8.0528e-01, 1.6668e-01, 2.8034e-02],
#         [2.7548e-07, 2.8069e-07, 1.0000e+00],
#         [4.0433e-01, 1.2666e-02, 5.8300e-01],
#         [8.6435e-07, 5.2622e-06, 9.9999e-01],
#         [9.9800e-01, 1.8381e-04, 1.8115e-03],
#         [9.9971e-01, 2.8970e-04, 1.2022e-06],
#         [1.8096e-01, 4.6690e-01, 3.5214e-01],
#         [9.5649e-01, 1.8867e-05, 4.3493e-02],
#         [4.1464e-03, 8.7949e-06, 9.9584e-01],
#         [9.9815e-01, 1.5133e-04, 1.6984e-03],
#         [5.5535e-08, 1.0000e+00, 4.0950e-09],
#         [1.3006e-06, 9.7086e-06, 9.9999e-01],
#         [2.0192e-02, 9.3368e-03, 9.7047e-01],
#         [8.8829e-02, 1.1947e-04, 9.1105e-01],
#         [9.6277e-08, 5.6845e-07, 1.0000e+00],
#         [9.5362e-04, 3.9362e-01, 6.0543e-01],
#         [2.3940e-06, 8.6527e-06, 9.9999e-01],
#         [1.6374e-07, 1.0000e+00, 1.6570e-07],
#         [8.4418e-01, 1.3660e-01, 1.9221e-02],
#         [1.7803e-04, 7.5912e-01, 2.4071e-01],
#         [2.6099e-01, 7.3829e-01, 7.2824e-04],
#         [3.6446e-03, 9.8712e-04, 9.9537e-01],
#         [4.2953e-04, 4.5974e-05, 9.9952e-01],
#         [2.0549e-08, 1.0000e+00, 1.1996e-08],
#         [2.0615e-05, 9.9990e-01, 8.4154e-05],
#         [9.9993e-01, 6.7077e-05, 4.8677e-07],
#         [1.1204e-05, 9.9998e-01, 6.3273e-06],
#         [2.7905e-05, 1.0508e-05, 9.9996e-01],
#         [8.6274e-01, 5.5227e-05, 1.3721e-01],
#         [1.6697e-03, 1.7040e-03, 9.9663e-01],
#         [7.3108e-06, 4.8206e-05, 9.9994e-01],
#         [1.0000e+00, 9.4452e-07, 1.1364e-06],
#         [9.5813e-07, 2.0898e-06, 1.0000e+00],
#         [9.3262e-06, 9.9999e-01, 2.2959e-06],
#         [1.8525e-07, 1.0000e+00, 1.8265e-07],
#         [4.0975e-09, 1.0000e+00, 2.0819e-09],
#         [5.5927e-09, 1.0000e+00, 4.3201e-09],
#         [3.0916e-09, 1.0000e+00, 1.2611e-09],
#         [2.5214e-08, 1.0000e+00, 4.4170e-09],
#         [9.3816e-01, 9.0815e-05, 6.1746e-02],
#         [9.9995e-01, 4.5665e-05, 3.1428e-06],
#         [2.4394e-02, 1.4448e-03, 9.7416e-01]], grad_fn=<SoftmaxBackward0>)

# %%
t_df[["positive", "negative", "neutral"]] = np.array(predictions.tolist()).round(
    decimals=2
)
t_df
# Out:
# /var/folders/0r/w8vqcgg56n9113ksf0mt1n940000gn/T/ipykernel_56984/430998590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_df[["positive", "negative", "neutral"]] = np.array(predictions.tolist()).round(decimals=2)
#       id ticker                                              title  \
# 0   4235   AAPL  Microsoft, Alphabet, Meta, Apple, And Amazon L...
# 1   4376   AAPL  Benzinga Before The Bell: More Amazon Workers ...
# 2      3   AAPL  Market Rebounds On Trade Optimism, Tech Bounce...
# 3      4   AAPL  American Shippers And Carriers React To Signs ...
# 4      5   AAPL  TD Ameritrade IMX Continued Its Dip In Decembe...
# ..   ...    ...                                                ...
# 95   133   AAPL  Mid-Afternoon Market Update: Nu Skin Enterpris...
# 96   135   AAPL                   60 Biggest Movers From Yesterday
# 97   137   AAPL  After Sliding On Powell's Words, Stocks Look F...
# 98   139   AAPL  Learn About The Everything Store To The Everyt...
# 99   142   AAPL  Tariff-Related Losses Put Pressure On Multinat...
#
#                                                   url  \
# 0   https://www.benzinga.com/news/earnings/22/07/2...
# 1   https://www.benzinga.com/news/22/08/28532545/b...
# 2              https://www.benzinga.com/node/12934767
# 3              https://www.benzinga.com/node/12938837
# 4              https://www.benzinga.com/node/12953011
# ..                                                ...
# 95             https://www.benzinga.com/node/13643990
# 96             https://www.benzinga.com/node/13649199
# 97             https://www.benzinga.com/node/13652243
# 98             https://www.benzinga.com/node/13656252
# 99             https://www.benzinga.com/node/13688513
#
#                                               article        date  positive  \
# 0   (Monday Market Open) Investors appear optimist...  2022-07-25      0.00
# 1   CNBCBlackRock To Pledge A$1B In Australian Bat...  2022-08-17      0.53
# 2   A stronger-than-expected government report on ...  2019-01-04      0.00
# 3   The first week of 2019 saw three of America's ...  2019-01-07      0.00
# 4   Declining for the third month in a row, TD Ame...  2019-01-08      0.00
# ..                                                ...         ...       ...
# 95  Toward the end of trading Wednesday, the Dow t...  2019-05-01      0.00
# 96  Loading...Loading...Gainers\nARCA biopharma, I...  2019-05-02      0.00
# 97  The Fed threw one right down the middle late W...  2019-05-02      0.94
# 98   In 2013, when Brad Stone set out to write abo...  2019-05-02      1.00
# 99  When tariff fears flare, most other market new...  2019-05-07      0.02
#
#     negative  neutral
# 0       0.00     1.00
# 1       0.44     0.03
# 2       1.00     0.00
# 3       0.00     1.00
# 4       0.00     1.00
# ..       ...      ...
# 95      1.00     0.00
# 96      1.00     0.00
# 97      0.00     0.06
# 98      0.00     0.00
# 99      0.00     0.97
#
# [100 rows x 9 columns]
