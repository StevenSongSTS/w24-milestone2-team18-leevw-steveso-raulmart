# %%
from db_helper_functions import (
    get_stock_news_with_finbert_scores_from_db,
    get_stock_news_with_finbert_tone_scores_from_db,
    get_stock_news_with_finbert_whole_article_scores_from_db,
    get_stock_news_with_finbert_tone_whole_article_scores_from_db,
    get_stock_news_with_bertopic_sentiment_scores_from_db,
)

# %%
get_stock_news_with_finbert_scores_from_db("AAPL").head()
# Out:
#      id ticker        date                                              title  \
# 0  4235   AAPL  2022-07-25  Microsoft, Alphabet, Meta, Apple, And Amazon L...
# 1  4376   AAPL  2022-08-17  Benzinga Before The Bell: More Amazon Workers ...
# 2     3   AAPL  2019-01-04  Market Rebounds On Trade Optimism, Tech Bounce...
# 3     4   AAPL  2019-01-07  American Shippers And Carriers React To Signs ...
# 4     5   AAPL  2019-01-08  TD Ameritrade IMX Continued Its Dip In Decembe...
#
#                                              summary  positive  negative  \
# 0  (Monday Market Open) Investors appear optimist...    0.4491    0.5199
# 1  CNBCBlackRock To Pledge A$1B In Australian Bat...    0.1263    0.7403
# 2  A stronger-than-expected government report on ...    0.1429    0.8077
# 3  The first week of 2019 saw three of America's ...    0.0076    0.9757
# 4  Declining for the third month in a row, TD Ame...    0.0156    0.9215
#
#    neutral
# 0   0.0310
# 1   0.1335
# 2   0.0493
# ...

# %%
get_stock_news_with_finbert_tone_scores_from_db("AAPL").head()
# Out:
#      id ticker        date                                              title  \
# 0  4235   AAPL  2022-07-25  Microsoft, Alphabet, Meta, Apple, And Amazon L...
# 1  4376   AAPL  2022-08-17  Benzinga Before The Bell: More Amazon Workers ...
# 2     3   AAPL  2019-01-04  Market Rebounds On Trade Optimism, Tech Bounce...
# 3     4   AAPL  2019-01-07  American Shippers And Carriers React To Signs ...
# 4     5   AAPL  2019-01-08  TD Ameritrade IMX Continued Its Dip In Decembe...
#
#                                              summary  positive  negative  \
# 0  (Monday Market Open) Investors appear optimist...    0.0000    1.0000
# 1  CNBCBlackRock To Pledge A$1B In Australian Bat...    0.9988    0.0011
# 2  A stronger-than-expected government report on ...    0.0016    0.0019
# 3  The first week of 2019 saw three of America's ...    0.0000    0.0000
# 4  Declining for the third month in a row, TD Ame...    0.0000    1.0000
#
#    neutral
# 0   0.0000
# 1   0.0001
# 2   0.9964
# ...

# %%
get_stock_news_with_finbert_whole_article_scores_from_db("AAPL").head()
# Out:
#      id ticker                                              title  \
# 0  4235   AAPL  Microsoft, Alphabet, Meta, Apple, And Amazon L...
# 1  4376   AAPL  Benzinga Before The Bell: More Amazon Workers ...
# 2     3   AAPL  Market Rebounds On Trade Optimism, Tech Bounce...
# 3     4   AAPL  American Shippers And Carriers React To Signs ...
# 4     5   AAPL  TD Ameritrade IMX Continued Its Dip In Decembe...
#
#                                                  url  \
# 0  https://www.benzinga.com/news/earnings/22/07/2...
# 1  https://www.benzinga.com/news/22/08/28532545/b...
# 2             https://www.benzinga.com/node/12934767
# 3             https://www.benzinga.com/node/12938837
# 4             https://www.benzinga.com/node/12953011
#
#                                              article        date  positive  \
# 0  (Monday Market Open) Investors appear optimist...  2022-07-25    0.2575
# 1  CNBCBlackRock To Pledge A$1B In Australian Bat...  2022-08-17    0.2965
# ...

# %%
get_stock_news_with_finbert_tone_whole_article_scores_from_db("AAPL").head()
# Out:
#      id ticker                                              title  \
# 0  4235   AAPL  Microsoft, Alphabet, Meta, Apple, And Amazon L...
# 1  4376   AAPL  Benzinga Before The Bell: More Amazon Workers ...
# 2     3   AAPL  Market Rebounds On Trade Optimism, Tech Bounce...
# 3     4   AAPL  American Shippers And Carriers React To Signs ...
# 4     5   AAPL  TD Ameritrade IMX Continued Its Dip In Decembe...
#
#                                                  url  \
# 0  https://www.benzinga.com/news/earnings/22/07/2...
# 1  https://www.benzinga.com/news/22/08/28532545/b...
# 2             https://www.benzinga.com/node/12934767
# 3             https://www.benzinga.com/node/12938837
# 4             https://www.benzinga.com/node/12953011
#
#                                              article        date  positive  \
# 0  (Monday Market Open) Investors appear optimist...  2022-07-25    0.4032
# 1  CNBCBlackRock To Pledge A$1B In Australian Bat...  2022-08-17    0.5272
# ...

# %%
get_stock_news_with_bertopic_sentiment_scores_from_db("AAPL").head()
# Out:
#    id ticker                                              title  \
# 0   1   AAPL                   58 Biggest Movers From Yesterday
# 1   2   AAPL  Apple Lowers Revenue Expectations As China's M...
# 2   3   AAPL  Market Rebounds On Trade Optimism, Tech Bounce...
# 3   4   AAPL  American Shippers And Carriers React To Signs ...
# 4   5   AAPL  TD Ameritrade IMX Continued Its Dip In Decembe...
#
#                                       url  \
# 0  https://www.benzinga.com/node/12932897
# 1  https://www.benzinga.com/node/12933509
# 2  https://www.benzinga.com/node/12934767
# 3  https://www.benzinga.com/node/12938837
# 4  https://www.benzinga.com/node/12953011
#
#                                              article        date  positive  \
# 0  Loading...Loading...Gainers\nOHR Pharmaceutica...  2019-01-04  0.464299
# 1  Among news of poor performance in the Chinese ...  2019-01-04  0.543883
# 2  A stronger-than-expected government report on ...  2019-01-04  0.379343
# ...
